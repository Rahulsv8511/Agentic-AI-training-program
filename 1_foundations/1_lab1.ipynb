# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('GOOGLE_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins AIzaSyCX

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[5], line 6
#       1 # And now we'll create an instance of the OpenAI class
#       2 # If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
#       3 # If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
#       4 # If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)
# ----> 6 openai = OpenAI()
#
# File c:\Users\Astha\projects\agents\.venv\Lib\site-packages\openai\_client.py:135, in OpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     133     api_key = os.environ.get("OPENAI_API_KEY")
#     134 if api_key is None:
# --> 135     raise OpenAIError(
#     136         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     137     )
#     138 if callable(api_key):
#     139     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)

# %%
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
google_api_key = os.getenv("GOOGLE_API_KEY")
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)
response = gemini.chat.completions.create(model="gemini-2.5-flash", messages=[{"role":"user", "content": "what is 2+2?"}])
print(response.choices[0].message.content)
# Out:
# 2 + 2 = 4

# %%
question ="what is the Israel Iran war all about"
message = [{"role":"user","content":question}] 
response = gemini.chat.completions.create(model="gemini-2.5-flash", messages=message)
print(response.choices[0].message.content)
# Out:
# The "Israel-Iran war" is a complex, long-standing, and primarily indirect conflict, often referred to as a **proxy war** or **shadow war**, though it has seen recent direct confrontations. It's not a conventional war with armies clashing across a border, but rather a multifaceted struggle for regional dominance and security, driven by deep ideological differences and strategic objectives.
#
# Here's a breakdown of what it's all about:
#
# 1.  **Ideological Opposition:**
#     *   **Iran:** Since the 1979 Islamic Revolution, Iran's ideology has been fiercely anti-Zionist, viewing Israel as an illegitimate entity ("the Zionist regime") and an extension of Western imperialism in the Middle East. Supporting Palestinian resistance and "liberating" Jerusalem are central tenets.
#     *   **Israel:** Views Iran's revolutionary ideology, its nuclear program, and its calls for Israel's destruction as an existential threat to its security and the safety of its citizens.
#
# 2.  **Iran's Regional Ambitions and "Axis of Resistance":**
#     *   Iran seeks to project its power and influence across the Middle East, challenging the US and its allies (including Israel and Saudi Arabia).
#     *   It has built an extensive network of proxy militias and allied groups across the region, collectively known as the "Axis of Resistance." These include:
#         *   **Hezbollah in Lebanon:** Iran's most powerful and heavily armed proxy, a constant threat on Israel's northern border.
#         *   **Hamas and Palestinian Islamic Jihad (PIJ) in Gaza:** Supported by Iran, these groups conduct attacks against Israel.
#         *   **Various Shiite militias in Syria and Iraq:** Used to maintain Iranian influence, protect supply lines, and threaten Israel from the Syrian Golan Heights.
#         *   **The Houthi movement in Yemen:** Supported by Iran, they've launched missiles and drones at Israel and disrupted Red Sea shipping.
#     *   This "Axis" aims to encircle Israel and exert pressure, as well as to expand Iranian revolutionary influence.
#
# 3.  **Israel's Security Concerns:**
#     *   **Iran's Nuclear Program:** Israel views a nuclear-armed Iran as an unacceptable existential threat and has historically advocated for military action if diplomacy fails to prevent it. It believes Iran is pursuing nuclear weapons despite its claims of a peaceful program.
#     *   **Iranian Entrenchment in Syria:** Israel has conducted hundreds of airstrikes in Syria against Iranian targets and Hezbollah, aiming to prevent Iran from establishing permanent military bases near its border and transferring advanced weapons to Hezbollah.
#     *   **Proxy Attacks:** Israel constantly faces threats from rockets, missiles, and drones launched by Iranian-backed groups from Gaza, Lebanon, Syria, and even Yemen.
#
# 4.  **How the "Shadow War" Plays Out:**
#     *   **Airstrikes in Syria:** Israel frequently bombs Iranian targets and weapons convoys destined for Hezbollah.
#     *   **Covert Operations:** Both sides are suspected of engaging in cyberattacks, assassinations of scientists, and sabotage operations against each other's infrastructure (e.g., Israel's alleged role in targeting Iranian nuclear facilities).
#     *   **Naval Warfare:** Accusations of attacks on commercial shipping in the Persian Gulf and Red Sea.
#     *   **Support for Proxies:** Iran provides funding, training, and weapons to its proxies; Israel counters these groups militarily.
#
# 5.  **Recent Escalation and Direct Confrontation (April 2024):**
#     *   The conflict significantly escalated in April 2024.
#     *   **April 1:** Israel launched an airstrike on an Iranian consulate building in Damascus, Syria, killing several senior IRGC (Iranian Revolutionary Guard Corps) commanders. Israel saw this as targeting military leaders responsible for attacks, while Iran viewed it as an attack on its sovereign territory.
#     *   **April 13:** Iran responded with an unprecedented direct missile and drone attack on Israel, launching hundreds of projectiles. Most were intercepted by Israel and its allies (US, UK, France, Jordan). This was the first time Iran directly attacked Israeli territory from its own soil.
#     *   **April 19:** Israel conducted a limited retaliatory strike inside Iran, targeting an airbase near Isfahan, signaling its capability to strike within Iran while attempting to de-escalate.
#
# **In essence, the Israel-Iran war is about:**
#
# *   **Regional Power Struggle:** Who will dominate the Middle East?
# *   **Existential Threat:** Israel's fear of a nuclear Iran and Iran's stated aim to eliminate Israel.
# *   **Ideology:** A clash between revolutionary Shiite Islamism and Zionism.
# *   **Proxy Warfare:** Both sides using non-state actors to achieve their objectives without direct, open war (until recently).
#
# The recent direct exchanges marked a dangerous new phase, bringing the long-running shadow war into the open and raising fears of a wider, devastating regional conflict.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick a business area for an agentic AI opportunity which can be done individually by a person with the help of computer with minimum investment in India and is good for some easy quick money.Start the content with a heading 'Idea'"}]

# Then make the first call:

response = gemini.chat.completions.create(model="gemini-2.5-flash", messages=messages)
print(response.choices[0].message.content)
# Then read the business idea:

business_idea = response.choices[0].message.content

# And repeat! In the next message, include the business idea within the message
messages1 = [{    "role": "user",    "content": f"""Use this business idea:{business_idea} Now describe 1 specific pain-point in this area that could be solved with an agentic AI.
Be concrete and include why it’s a good target.Respond with just the pain-point.However start the message with a heading like 'Painpoint'""".strip()}]

response1 = gemini.chat.completions.create(
    model="gemini-2.5-flash",
    messages=messages1
)

print(response1.choices[0].message.content)
# Out:
# # Idea
#
# **Local Business AI Content & Engagement Engine**
#
# This business area leverages agentic AI to provide hyper-local, automated content creation and basic customer engagement services for small businesses in India.
#
# **The Opportunity:**
#
# Thousands of small and medium enterprises (SMEs) across India – from local kirana stores, salons, and tailors to home-based entrepreneurs, tutors, and small restaurants – desperately need a consistent online presence but lack the time, skills, or budget for professional marketing. They struggle to create engaging social media posts, WhatsApp updates, or simple promotional content. This is where an agentic AI opportunity shines.
#
# **How Agentic AI Makes it Work (Individually, Minimum Investment, Quick Money):**
#
# You, as the individual, act as the orchestrator and quality checker, while AI agents do the heavy lifting.
#
# 1.  **AI-Driven Niche Research & Persona Generation:**
#     *   **Agentic AI:** Given a business type (e.g., "local organic grocery store in Bangalore"), AI agents can automatically browse local online reviews, competitor social media, local news, and trending topics.
#     *   **Output:** The AI generates customer personas, common pain points, unique selling propositions (USPs) for the business, and content themes relevant to the local context (festivals, local events, specific customer needs).
#     *   **Why it's agentic:** The AI autonomously gathers and synthesizes data to build a strategic foundation.
#
# 2.  **Automated Content Creation & Scheduling:**
#     *   **Agentic AI:** Based on the generated insights, AI agents create a stream of diverse content:
#         *   **Social Media Posts:** Instagram captions, Facebook updates, Twitter tweets (if applicable), complete with relevant emojis, hashtags, and calls to action. It can even suggest accompanying image ideas or generate basic graphics.
#         *   **WhatsApp Broadcast Messages:** Short, engaging messages for daily deals, new arrivals, or special announcements.
#         *   **Short Video Scripts:** Basic ideas and scripts for Reels/Shorts (e.g., "5 uses for our new product," "behind-the-scenes").
#         *   **Blog Post Outlines/Drafts:** Simple articles relevant to the business (e.g., "Benefits of using our organic produce," "Winter skincare tips from our salon").
#     *   **AI-Powered Scheduling:** Integrates with tools to automatically schedule these posts across platforms at optimal times.
#     *   **Why it's agentic:** The AI takes a high-level goal ("post 5 times this week about X, Y, Z") and autonomously generates specific content tailored to platforms and schedules it.
#
# 3.  **Basic Customer Interaction & FAQ Automation (Optional, but adds value):**
#     *   **Agentic AI:** Set up a simple AI chatbot (e.g., on WhatsApp Business or Facebook Messenger) to answer common FAQs about business hours, services, prices, or booking.
#     *   **Output:** Automated, instant responses, freeing up the business owner's time.
#     *   **Why it's agentic:** The chatbot autonomously handles initial customer queries without human intervention.
#
# **Why this fits the criteria:**
#
# *   **Agentic AI Opportunity:** The AI is performing complex tasks like research, content generation, and scheduling with minimal human input after initial setup and quality checks. It's not just a tool; it's acting semi-autonomously to achieve marketing goals.
# *   **Individually by a Person:** You are the one-person agency. Your role is to understand the client's needs, set up the AI agents, review their output, and communicate with clients. You can manage multiple clients simultaneously because the AI automates most of the time-consuming tasks.
# *   **Help of Computer:** A laptop/desktop with internet access is all you need. The "agentic" part comes from utilizing advanced AI models (LLMs, image generators) and automation tools.
# *   **Minimum Investment in India:**
#     *   **Almost Zero Upfront:** Start with free tiers of AI tools (ChatGPT, Bard, Midjourney/Stable Diffusion alternatives, Canva Free).
#     *   **Gradual Scaling:** As you get clients, you might invest in paid AI subscriptions or social media scheduling tools, but these are operational costs covered by client fees.
#     *   **No physical office, inventory, or employees needed.**
# *   **Easy Quick Money:**
#     *   **High Demand:** Small businesses are desperate for this help and willing to pay for it.
#     *   **Fast Delivery:** AI allows you to churn out weeks of content in hours, meaning you can onboard clients and deliver value almost immediately.
#     *   **Subscription Model:** Offer monthly packages (e.g., "Basic Social Media & WhatsApp Content Package" for ₹2,000-₹5,000 per month, depending on scope). Get a few clients, and you have quick recurring revenue.
#     *   **Tangible Results:** You deliver ready-to-post content, which clients can see and use immediately, making it easy to demonstrate value.
#
# **Getting Started:**
#
# 1.  **Identify a Niche:** Start with a specific type of local business (e.g., "salons," "tutors," "small restaurants") you understand.
# 2.  **Master Key AI Tools:** Get proficient with tools like:
#     *   **LLMs:** ChatGPT, Claude, Gemini (for text generation, research synthesis).
#     *   **Image Generators:** Midjourney, DALL-E 3, Stable Diffusion (for visual content suggestions or direct generation).
#     *   **Design Tools:** Canva (for quick graphic design, template usage).
#     *   **Scheduling Tools:** Buffer, Hootsuite, Later (many have free tiers for basic scheduling).
# 3.  **Create a Portfolio:** Generate content for 2-3 hypothetical businesses in your chosen niche to showcase your capabilities.
# 4.  **Reach Out:** Approach local businesses directly (in-person, phone, local WhatsApp groups) with your portfolio and a clear, affordable package. Emphasize how you'll save them time and grow their online presence.
#
# This idea leverages the power of AI to serve an underserved market, making it an excellent candidate for an individual seeking quick and relatively easy money with minimal investment in India.
# Painpoint
#
# Small business owners struggle to consistently generate fresh, locally relevant, and platform-optimized content for social media and WhatsApp, often leading to inconsistent online presence, generic messaging, and missed opportunities to engage with their specific local customer base during festivals, local events, or daily business updates.

# %%
message2=[{"role":"user", "content": f"""Take this pain point:{response1}Now propose the solution for this in few lines only."""}]
response2 = gemini.chat.completions.create(
    model="gemini-2.5-flash", messages=message2
)
print(response2.choices[0].message.content)
# Out:
# Develop an AI-powered content generator for Indian micro-businesses. It will create culturally resonant, Hinglish/regional marketing text and simple visuals, optimized for WhatsApp, Google My Business, and local social media, needing only basic inputs to overcome expertise and time constraints.
